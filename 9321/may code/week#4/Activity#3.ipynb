# %% [markdown]
# ## Activity#3

# %% [markdown]
# Description : This activity is also based on the iris dataset.
# You need to plot two scatter charts as shown as blow:

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Load the CSV file into a dataframe
df =pd.read_csv('iris.csv')
df.head()
df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
# Split the dataset into three dataframes based on the three species; 
#you can use panda's query method to filter rows as you did in the previous labs.
setosa_df = df.query('species == "setosa"')
versicolor_df = df.query('species == "versicolor"')
virginica_df = df.query('species == "virginica"')

# %%
# Plot a scatter chart using x='sepal_length', y='sepal_width', and separate colors for each of the three dataframes
ax = setosa_df.plot.scatter(x='sepal_length', y='sepal_width', label='setosa')
ax = versicolor_df.plot.scatter(x='sepal_length', y='sepal_width', label='versicolor', color='green', ax=ax)
ax = virginica_df.plot.scatter(x='sepal_length', y='sepal_width', label='virginica', color='red', ax=ax)

# %%
# Plot a scatter chart using x='petal_length', y='petal_width', 
#and separate colors for each of the three dataframes
ax=setosa_df.plot.scatter(x='petal_length',y='petal_width',label='Setosa')
ax = versicolor_df.plot.scatter(x='petal_length', y='petal_width', label='versicolor', c='green',ax=ax)
ax =  virginica_df.plot.scatter(x='petal_length', y='petal_width', label='virginica', c='red',ax=ax)
